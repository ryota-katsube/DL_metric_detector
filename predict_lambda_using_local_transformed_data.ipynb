# %% [markdown]
# # Goal of this python notebook

# %% [markdown]
# In this python notebook, we see that a DL model is able to predict $ λ$ , which characterizes the metric of 2+1 AdS, $$ ds^2 = -(1+λ^2 r^2)dt^2 + \frac{dr^2}{1+ λ^2 r^2} + dϕ^2,
# $$ by a simulation using images which are applied by a local coordinate transformation.  We consider the following local coordinate transformation,
# $$ x^{\prime} = x + 0.1 \cos(nxy), \\
# y^{\prime} = y + 0.1 \sin(nxy), $$
# where $x = r \cos \phi$, $y = r \sin \phi$ and $n$ is an integer between 1 and 4.

# %% [markdown]
# # Import library

# %% [markdown]
# We first import some libraries.

# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten,Reshape
from keras.layers.convolutional import  Conv2D
from keras.layers.pooling import  MaxPooling2D
from keras.utils import np_utils

# %% [markdown]
# # Mounting the google drive

# %% [markdown]
# To save the dataset we will generate, we utilize the google drive in this notebook. So we have to mount the google drive.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Generate data

# %% [markdown]
# We first generate $(x,y)$ images of geodesics using the solution of the equation of motion of free particles in 2+1 AdS,
# $$ r = \frac{1}{λ} \sqrt{E - \sqrt{E^2 - λ^2 L^2} \sin2 λ \tau},$$
# $$\phi = \pm \arctan \left[  \frac{E}{\lambda L} \left( \tan λ \tau - \sqrt{1 - \left( \frac{λ L }{E}\right)^2} \right)\right] + \phi_0, $$
# $$ t = \frac{1}{\lambda} \arctan \left[ \frac{(1+E)\tanλ\tau - \sqrt{E^2 - λ^2 L^2}}{\sqrt{1+2E+λ^2 L^2}} \right] + t_0 ,$$
# where $E$  is a positive constant associated with energy, $L$ is a real constant associated with angular momentum, and
# $t_0$ $(ϕ_0)$ is an integration constant for $t (ϕ )$.

# %% [markdown]
# We generate $\lambda$, $E$, $L$, $t_0$ and $\phi_0$ at random. We set the range of them to
# $ 0 \leq E < 10$, $0 \leq L < \frac{E}{λ}$ , $ 0 \leq \phi_0 <2 \pi$ and $ 0 \leq t_0 <2 \pi$.
# The value of $λ$ is chosen as an integer between 1 and 4 for simplity.

# %%
def generate_initial_state(num_particle):
  # num_particle means the number of particles/trajectories in one image.

  # lambda_rand means the value of lambda in 2+1 AdS metric.
  lambda_rand  = np.random.randint(1,5) # 1 <= \lambda <5 to avoid singularity 
  E_rand = np.random.rand(num_particle)*10 # E_rand represents E.
  L_rand =  np.random.rand(num_particle)* E_rand / lambda_rand  # L_rand represents L.
  phi_rand = np.random.rand(num_particle)* 2 *np.pi - np.pi #phi_rand represents \phi_0.
  
  return E_rand,L_rand,phi_rand,lambda_rand

# %% [markdown]
# We calculate the geodesic of one particle using the solution of the equation of motion.

# %%
def time_evolve(t,E,L,lambda0,phi0):
    
  r = 1 / lambda0 *  np.sqrt(E - np.sqrt(E ** 2 - (lambda0 ** 2) * (L ** 2) ) * np.sin(2 * lambda0 * t) )

  Y = E * (np.tan(lambda0 * t) - np.sqrt(1- (lambda0 * L / E)**2 ) )
  X = lambda0 * L
  phi = np.arctan2(Y,X) + phi0
  return r,phi

# %% [markdown]
# Next, we define a function whish returns an image in which the local coordinate transformation is applied.

# %%
def generate_one_data_LocalTrans(num_particle):

  delta_t = 0.005 #delta_t represents the slice of \tau.
  
  # Because \tau is the argument of trigonometric functions sin(2 \lambda \tau) and tan(\lambda \tau), we can set the range of $\tau$ to $ 0 \leq \tau < \pi.
  time_frame = int(np.ceil(np.pi / delta_t))  # tau_frame is the number of frames.

  # setting the number of pixels in a image.
  pixel_num = 200

  # setting the width and height of images. 10 comes from the maximum value of E we set.
  h = 10

  delta_xy = h/pixel_num #delta_xy represents the slice of images.

  E_rand, L_rand,phi_rand,lambda_rand = generate_initial_state(num_particle)

  #\phi has a freedom of sign and we assign the sign by binomial random variables. 
  sign = np.random.binomial(1,0.5,size=num_particle)

  # choosing n at random. n is the integer which charcterizes the local transformation.
  n = np.random.randint(1,4) 
 
  temp = []
  # obtaining (x^{\prime},y^{\prime}) arrays from  (r,\phi) arrays.
  for i in range(0,time_frame): 
      # i is the counter for the frame number.

      for j in range(num_particle):
        # j is the counter for the particle number.

        r,phi = time_evolve(i * delta_t, E_rand[j],L_rand[j],lambda_rand,phi_rand[j])
        # x and y are coordinates before the transformation.
        x = ((-1) ** sign[j]  )   * r * np.cos(phi) 
        y =  r * np.sin(phi)

        # x_new and y_nes are coordinates after the transformation.
        x_new = x +  0.1 * np.cos(n*x * y) 
        y_new = y + 0.1  * np.sin(n*x * y) 

        # discretizing x and y by delta_xy and using the symmetry of orbits
        
        temp.append( [int(np.floor((x_new+h/2)/delta_xy)), int(np.floor((y_new+h/2)/delta_xy))])
        temp.append( [int(np.floor((-x_new+h/2)/delta_xy)), int(np.floor((-y_new+h/2)/delta_xy))])

  xy_image = np.zeros([pixel_num, pixel_num,1])
  for item in temp:
      x = int(item[0])
      y = int(item[1])
      xy_image[x,y,0] = 1
  
  return xy_image,lambda_rand

# %% [markdown]
# We make $(x^{\prime}, y^{\prime})$ image dataset using generate_one_data_LocalTrans function we defined.

# %%
def generate_LocalTrans_data(num_data,num_particle):
  data_x = [] # to save x^{\prime} y^{\prime} images
  data_y = [] # to save lambda values
  for i in range(num_data):
    x,y = generate_one_data_LocalTrans(num_particle)
    data_x.append(x)
    data_y.append(y)

  return data_x,data_y

# %% [markdown]
# We set num_particle = 15  and num_data = 4000 and generate dataset  using functions we defined above.

# %%
#setting parameters
num_particle = 15
num_learning_data = 4000 

# We generate 2800 training data, 800 validation data and 400 test data.
x_train,y_train = generate_LocalTrans_data(int(0.7*num_learning_data),num_particle)
x_vali,y_vali = generate_LocalTrans_data(int(0.2*num_learning_data),num_particle)
x_test,y_test = generate_LocalTrans_data(int(0.1*num_learning_data),num_particle)

x_train = np.array(x_train)
x_vali = np.array(x_vali)
x_test = np.array(x_test)

y_train = np.array(y_train)
y_vali = np.array(y_vali)
y_test = np.array(y_test)

# %% [markdown]
# We save the dataset numpy array in the google drive. Note that you may have to replace the file path which shows where the dataset array is saved, according to your folder structure.

# %%
# saving the data in npz file
# replacing the file path accodring to your coding environment.
file_path = "/content/drive/My Drive/Colab Notebooks/metric_detecter_public"
# You can replace the  "/dataset_local_trans" to your favorite name of npz file.
np.savez_compressed(file_path + '/dataset_local_trans', x_train, y_train,x_vali,y_vali,x_test,y_test)

# %% [markdown]
# # Printing some images and Preprocessing

# %% [markdown]
# We perform some preprocessing and print some $(x^{\prime},y^{\prime})$ images.

# %%
# reloading the data from npz file
# replacing the file path accodring to your coding environment.
file_path = "/content/drive/My Drive/Colab Notebooks/metric_detecter_public"
dataset_array = np.load(file_path + '/dataset_local_trans.npz')
x_train = dataset_array["arr_0"]
y_train = dataset_array["arr_1"]
x_vali = dataset_array["arr_2"]
y_vali = dataset_array["arr_3"]
x_test = dataset_array["arr_4"]
y_test = dataset_array["arr_5"]

# %%
# showing some examples of images.
for i in range(5):
  plt.imshow(x_train[i][:,:,0])
  
  print("value of lambda:",y_train[i])
  plt.show()
# Out:
# value of lambda: 4
# value of lambda: 4
# value of lambda: 4
# value of lambda: 4
# value of lambda: 1

# %%
# converting target labels to one-hot vectors.
y_train = y_train -1
y_vali = y_vali -1
y_test = y_test -1
y_train_one_hot = np_utils.to_categorical(y_train,4)
y_vali_one_hot = np_utils.to_categorical(y_vali,4)
y_test_one_hot = np_utils.to_categorical(y_test,4)

# %% [markdown]
# # Training a DL model

# %% [markdown]
# Here, we train a DL model.  We use CNN. It's structure is the following.

# %%
input_shape = x_train[0,:,:,:].shape
model = Sequential()
model.add(Conv2D(5, (5,5), strides=(1, 1), input_shape=input_shape,padding='same', dilation_rate=(1, 1),activation='tanh', use_bias=True))
model.add(MaxPooling2D(pool_size=(3, 3), padding='same'))

model.add(Conv2D(5, (5,5), strides=(1, 1),padding='same',activation='tanh', use_bias=True))
model.add(MaxPooling2D(pool_size=(3, 3), padding='same'))
model.add(Conv2D(5, (3,3), strides=(1, 1),padding='same',activation='tanh', use_bias=True))
model.add(MaxPooling2D(pool_size=(3, 3), padding='same'))
model.add(Conv2D(3, (3,3), strides=(1, 1),padding='same',activation='tanh', use_bias=True))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model.add(Conv2D(2, (2,2), strides=(1, 1),padding='same',activation='tanh', use_bias=True))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model.add(Conv2D(2, (2,2), strides=(1, 1),padding='same',activation='tanh', use_bias=True))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(10,activation='tanh'))
model.add(Dropout(0.5))
model.add(Dense(5,activation='tanh'))
model.add(Dense(4,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 200, 200, 5)       130
#
#  max_pooling2d (MaxPooling2D  (None, 67, 67, 5)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 67, 67, 5)         630
#
#  max_pooling2d_1 (MaxPooling  (None, 23, 23, 5)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 23, 23, 5)         230
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 5)          0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 3)           138
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 3)          0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 4, 4, 2)           26
#
#  max_pooling2d_4 (MaxPooling  (None, 2, 2, 2)          0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 2, 2, 2)           18
#
#  flatten (Flatten)           (None, 8)                 0
#
#  dropout (Dropout)           (None, 8)                 0
#
#  dense (Dense)               (None, 10)                90
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dense_2 (Dense)             (None, 4)                 24
#
# =================================================================
# Total params: 1,341
# Trainable params: 1,341
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The loss function of this task is the categorical crossentropy and we use ADAM as a optimizer. We train the model for 150 epochs.

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])
history = model.fit(x_train, y_train_one_hot,
                    batch_size=50,
                    epochs=150,
                    verbose=1,
                    validation_data=(x_vali, y_vali_one_hot))
score = model.evaluate(x_test, y_test_one_hot, verbose=0)
# Out:
# Epoch 1/150
# 56/56 [==============================] - 13s 16ms/step - loss: 1.3713 - accuracy: 0.2907 - val_loss: 1.3342 - val_accuracy: 0.4688
# Epoch 2/150
# 56/56 [==============================] - 1s 9ms/step - loss: 1.2684 - accuracy: 0.4332 - val_loss: 1.1040 - val_accuracy: 0.5063
# Epoch 3/150
# 56/56 [==============================] - 1s 9ms/step - loss: 1.0650 - accuracy: 0.5382 - val_loss: 0.8984 - val_accuracy: 0.5075
# Epoch 4/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.9260 - accuracy: 0.5675 - val_loss: 0.7782 - val_accuracy: 0.7025
# Epoch 5/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.8460 - accuracy: 0.6164 - val_loss: 0.6821 - val_accuracy: 0.7013
# Epoch 6/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.7533 - accuracy: 0.6946 - val_loss: 0.5665 - val_accuracy: 0.8550
# Epoch 7/150
# 56/56 [==============================] - 1s 10ms/step - loss: 0.6899 - accuracy: 0.7243 - val_loss: 0.4906 - val_accuracy: 0.9688
# Epoch 8/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.6404 - accuracy: 0.7579 - val_loss: 0.4403 - val_accuracy: 0.9762
# Epoch 9/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.5891 - accuracy: 0.7804 - val_loss: 0.3923 - val_accuracy: 0.9812
# Epoch 10/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.5494 - accuracy: 0.8061 - val_loss: 0.3232 - val_accuracy: 0.9712
# Epoch 11/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.5113 - accuracy: 0.8221 - val_loss: 0.3010 - val_accuracy: 0.9737
# Epoch 12/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.4774 - accuracy: 0.8311 - val_loss: 0.2420 - val_accuracy: 0.9837
# Epoch 13/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.4494 - accuracy: 0.8461 - val_loss: 0.2125 - val_accuracy: 0.9850
# Epoch 14/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.4235 - accuracy: 0.8604 - val_loss: 0.1874 - val_accuracy: 0.9900
# Epoch 15/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.3916 - accuracy: 0.8668 - val_loss: 0.1648 - val_accuracy: 0.9912
# Epoch 16/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.3679 - accuracy: 0.8746 - val_loss: 0.1451 - val_accuracy: 0.9937
# Epoch 17/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.3563 - accuracy: 0.8754 - val_loss: 0.1291 - val_accuracy: 0.9950
# Epoch 18/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.3419 - accuracy: 0.8829 - val_loss: 0.1297 - val_accuracy: 0.9850
# Epoch 19/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.3219 - accuracy: 0.8900 - val_loss: 0.1084 - val_accuracy: 0.9925
# Epoch 20/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.2954 - accuracy: 0.9054 - val_loss: 0.1212 - val_accuracy: 0.9825
# Epoch 21/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.3155 - accuracy: 0.8864 - val_loss: 0.0954 - val_accuracy: 0.9900
# Epoch 22/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0
150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1424 - accuracy: 0.9339 - val_loss: 0.0199 - val_accuracy: 0.9950
# Epoch 81/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1382 - accuracy: 0.9371 - val_loss: 0.0169 - val_accuracy: 0.9975
# Epoch 82/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1606 - accuracy: 0.9254 - val_loss: 0.0262 - val_accuracy: 0.9937
# Epoch 83/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1548 - accuracy: 0.9243 - val_loss: 0.0238 - val_accuracy: 0.9937
# Epoch 84/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1246 - accuracy: 0.9425 - val_loss: 0.0186 - val_accuracy: 0.9962
# Epoch 85/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1402 - accuracy: 0.9304 - val_loss: 0.0214 - val_accuracy: 0.9962
# Epoch 86/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1369 - accuracy: 0.9354 - val_loss: 0.0202 - val_accuracy: 0.9962
# Epoch 87/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1394 - accuracy: 0.9307 - val_loss: 0.0214 - val_accuracy: 0.9962
# Epoch 88/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1254 - accuracy: 0.9425 - val_loss: 0.0218 - val_accuracy: 0.9950
# Epoch 89/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1391 - accuracy: 0.9325 - val_loss: 0.0185 - val_accuracy: 0.9950
# Epoch 90/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1401 - accuracy: 0.9293 - val_loss: 0.0186 - val_accuracy: 0.9962
# Epoch 91/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1319 - accuracy: 0.9404 - val_loss: 0.0220 - val_accuracy: 0.9950
# Epoch 92/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1314 - accuracy: 0.9357 - val_loss: 0.0223 - val_accuracy: 0.9950
# Epoch 93/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1226 - accuracy: 0.9425 - val_loss: 0.0200 - val_accuracy: 0.9962
# Epoch 94/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1446 - accuracy: 0.9343 - val_loss: 0.0195 - val_accuracy: 0.9962
# Epoch 95/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1185 - accuracy: 0.9479 - val_loss: 0.0149 - val_accuracy: 0.9962
# Epoch 96/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1273 - accuracy: 0.9468 - val_loss: 0.0234 - val_accuracy: 0.9950
# Epoch 97/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1359 - accuracy: 0.9311 - val_loss: 0.0159 - val_accuracy: 0.9975
# Epoch 98/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1234 - accuracy: 0.9404 - val_loss: 0.0221 - val_accuracy: 0.9950
# Epoch 99/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1273 - accuracy: 0.9443 - val_loss: 0.0182 - val_accuracy: 0.9962
# Epoch 100/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1274 - accuracy: 0.9357 - val_loss: 0.0165 - val_accuracy: 0.9975
# Epoch 101/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1206 - accuracy: 0.9429 - val_loss: 0.0291 - val_accuracy: 0.9937
# Epoch 102/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1299 - accuracy: 0.9414 - val_loss: 0.0269 - val_accuracy: 0.9925
# Epoch 103/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1241 - accuracy: 0.9382 - val_loss: 0.0140 - val_accuracy: 0.9975
# Epoch 104/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1383 - accuracy: 0.9321 - val_loss: 0.0140 - val_accuracy: 0.9962
# Epoch 105/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1305 - accuracy: 0.9329 - val_loss: 0.0240 - val_accuracy: 0.9950
# Epoch 106/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1343 - accuracy: 0.9393 - val_loss: 0.0228 - val_accuracy: 0.9950
# Epoch 107/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1155 - accuracy: 0.9439 - val_loss: 0.0147 - val_accuracy: 0.9962
# Epoch 108/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1266 - accuracy: 0.9400 - val_loss: 0.0158 - val_accuracy: 0.9937
# Epoch 109/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1216 - accuracy: 0.9389 - val_loss: 0.0318 - val_accuracy: 0.9937
# Epoch 110/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1216 - accuracy: 0.9436 - val_loss: 0.0255 - val_accuracy: 0.9950
# Epoch 111/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1314 - accuracy: 0.9439 - val_loss: 0.0206 - val_accuracy: 0.9962
# Epoch 112/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1203 - accuracy: 0.9511 - val_loss: 0.0206 - val_accuracy: 0.9962
# Epoch 113/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1174 - accuracy: 0.9500 - val_loss: 0.0184 - val_accuracy: 0.9962
# Epoch 114/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1130 - accuracy: 0.9511 - val_loss: 0.0190 - val_accuracy: 0.9937
# Epoch 115/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1146 - accuracy: 0.9468 - val_loss: 0.0260 - val_accuracy: 0.9925
# Epoch 116/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1192 - accuracy: 0.9454 - val_loss: 0.0146 - val_accuracy: 0.9962
# Epoch 117/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1232 - accuracy: 0.9443 - val_loss: 0.0118 - val_accuracy: 0.9987
# Epoch 118/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1254 - accuracy: 0.9443 - val_loss: 0.0127 - val_accuracy: 0.9975
# Epoch 119/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1312 - accuracy: 0.9400 - val_loss: 0.0108 - val_accuracy: 0.9987
# Epoch 120/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1164 - accuracy: 0.9521 - val_loss: 0.0298 - val_accuracy: 0.9925
# Epoch 121/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1274 - accuracy: 0.9429 - val_loss: 0.0193 - val_accuracy: 0.9937
# Epoch 122/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1196 - accuracy: 0.9450 - val_loss: 0.0207 - val_accuracy: 0.9950
# Epoch 123/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1262 - accuracy: 0.9414 - val_loss: 0.0129 - val_accuracy: 0.9962
# Epoch 124/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1178 - accuracy: 0.9507 - val_loss: 0.0233 - val_accuracy: 0.9950
# Epoch 125/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1144 - accuracy: 0.9511 - val_loss: 0.0149 - val_accuracy: 0.9962
# Epoch 126/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1114 - accuracy: 0.9500 - val_loss: 0.0191 - val_accuracy: 0.9962
# Epoch 127/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1249 - accuracy: 0.9429 - val_loss: 0.0166 - val_accuracy: 0.9937
# Epoch 128/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1270 - accuracy: 0.9425 - val_loss: 0.0366 - val_accuracy: 0.9875
# Epoch 129/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1115 - accuracy: 0.9482 - val_loss: 0.0173 - val_accuracy: 0.9950
# Epoch 130/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1275 - accuracy: 0.9446 - val_loss: 0.0273 - val_accuracy: 0.9937
# Epoch 131/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1175 - accuracy: 0.9464 - val_loss: 0.0238 - val_accuracy: 0.9950
# Epoch 132/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1025 - accuracy: 0.9564 - val_loss: 0.0191 - val_accuracy: 0.9950
# Epoch 133/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1111 - accuracy: 0.9511 - val_loss: 0.0192 - val_accuracy: 0.9950
# Epoch 134/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1091 - accuracy: 0.9518 - val_loss: 0.0163 - val_accuracy: 0.9962
# Epoch 135/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1140 - accuracy: 0.9489 - val_loss: 0.0181 - val_accuracy: 0.9962
# Epoch 136/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1244 - accuracy: 0.9443 - val_loss: 0.0210 - val_accuracy: 0.9950
# Epoch 137/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1077 - accuracy: 0.9511 - val_loss: 0.0226 - val_accuracy: 0.9925
# Epoch 138/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1211 - accuracy: 0.9471 - val_loss: 0.0193 - val_accuracy: 0.9950
# Epoch 139/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1201 - accuracy: 0.9421 - val_loss: 0.0236 - val_accuracy: 0.9937
# Epoch 140/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1146 - accuracy: 0.9439 - val_loss: 0.0159 - val_accuracy: 0.9950
# Epoch 141/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1177 - accuracy: 0.9504 - val_loss: 0.0248 - val_accuracy: 0.9937
# Epoch 142/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1267 - accuracy: 0.9418 - val_loss: 0.0442 - val_accuracy: 0.9900
# Epoch 143/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1144 - accuracy: 0.9482 - val_loss: 0.0131 - val_accuracy: 0.9975
# Epoch 144/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1144 - accuracy: 0.9493 - val_loss: 0.0142 - val_accuracy: 0.9962
# Epoch 145/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1155 - accuracy: 0.9486 - val_loss: 0.0225 - val_accuracy: 0.9950
# Epoch 146/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1286 - accuracy: 0.9425 - val_loss: 0.0162 - val_accuracy: 0.9962
# Epoch 147/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1133 - accuracy: 0.9482 - val_loss: 0.0132 - val_accuracy: 0.9975
# Epoch 148/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1156 - accuracy: 0.9486 - val_loss: 0.0158 - val_accuracy: 0.9962
# Epoch 149/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1174 - accuracy: 0.9439 - val_loss: 0.0404 - val_accuracy: 0.9900
# Epoch 150/150
# 56/56 [==============================] - 1s 9ms/step - loss: 0.1241 - accuracy: 0.9443 - val_loss: 0.0214 - val_accuracy: 0.9937

# %% [markdown]
# We check the value of the loss function for test data and plot how loss functions for training data and validation data change as the model learnes.

# %%
print('The loss function for test data:', score[0])
plt.plot(history.history['loss'], marker='.', label='loss')
plt.plot(history.history['val_loss'], marker='.', label='val_loss')
plt.title('model loss')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(loc='best')
plt.show()
# Out:
# The loss function for test data: 0.033196307718753815

# %% [markdown]
# We also check how the model accuracy varies.

# %%
plt.plot(history.history['accuracy'], marker='.', label='accuracy')
plt.plot(history.history['val_accuracy'], marker='.', label='val_accuracy')
plt.title('model accuracy')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# We see the model accuracy for test data.

# %%
print('The accuracy for test data:', score[1])
# Out:
# The accuracy for test data: 0.9925000071525574

# %% [markdown]
# Let's print some results of the predicting of DL. The title of each image shows the prediction and the blue (red) color of the title means the correct (incorrect) prediction. DL returns right answers for almost all images.

# %%
# calculating the prediction for test data
prediction = model.predict(x_test)
max_pred_index = np.argmax(prediction, axis=1)

# showing some images with prediction values.
num_rows = 3
num_cols = 4
plt.figure(figsize=(10,8))
plt.subplots_adjust( wspace = 0.5,hspace=0.7)

k = 0
plot_index = 1
for i in range(num_rows):
  for j in range(num_cols):
    plt.subplot(num_rows,num_cols,plot_index)
     
    plt.xlabel(r"$x$")
    plt.ylabel(r"$y$",rotation = "horizontal",labelpad=10)
    plt.imshow(x_test[k].reshape(200,200), cmap=plt.cm.gray_r,origin='lower') 
    if max_pred_index[k] == y_test[k]:
      title_color = "blue"
    else:
      title_color = "red"
    plt.title(f"Predicted answer:\n"r"$\lambda= $"f" {max_pred_index[k]+1}",color=title_color)
    k += 1
    plot_index += 1
